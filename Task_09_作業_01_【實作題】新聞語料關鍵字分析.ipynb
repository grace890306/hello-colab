# %% [markdown]
# <a href="https://colab.research.google.com/github/grace890306/hello-colab/blob/main/Task_09_%E4%BD%9C%E6%A5%AD_01_%E3%80%90%E5%AF%A6%E4%BD%9C%E9%A1%8C%E3%80%91%E6%96%B0%E8%81%9E%E8%AA%9E%E6%96%99%E9%97%9C%E9%8D%B5%E5%AD%97%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# 利用 requests 對 API 來源發送一個請求
response = requests.get('https://udn.com/news/breaknews/1')
soup = BeautifulSoup(response.text)

# 定義變數名稱
news=[]

for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]: #前四篇新聞
  news_url = link.a['href']
  news_response = requests.get('https://udn.com' + news_url)
  news_soup = BeautifulSoup(news_response.text)
  news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n',' ').replace('\r','')
  news.append(news_content)
  #print(news_content)
print(news)



# 安裝 jieba 中文斷詞套件
# !pip install jieba
# 下載官方字典檔
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big

# 載入套件與字典檔
import jieba
jieba.load_userdict("dict.txt.big")

# 精確模式斷詞
# 定義變數名稱
tokens=[]
for d in news:
  token = list(jieba.cut(d, HMM=False)) # token = d 字串斷詞結果
  tokens.append(token)
print(tokens)

word_count = {}
for row in tokens:
    for word in row:
        if word in word_count.keys():
            word_count[word] += 1
        else:
            word_count[word] = 1

# 依照出現次數由多到少進行排序
word_count = dict(sorted(word_count.items(), key=lambda item: item[1],reverse=True))
print(word_count)
# Out:
# ['雲林縣虎尾鎮長、麥寮鄉長補選結果出爐，藍營在搶下海線立委一席後，雲林縣長張麗善傾力輔選，再下一城由虎尾鎮代會主席林嘉弘拿下虎尾鎮長一席、麥寮鄉長惜敗，民進黨在失去海線立委蘇治芬後，虎尾鎮長補選未能光復、麥寮鄉長則由未獲黨提名的前鄉長許忠富當選，面對這次選舉結果，張麗善及民進黨雲林立委劉建國都說「要檢討」。  藍營支持的虎尾鎮代會主席林嘉弘拿下逾5成選票當選虎尾鎮長，麥寮鄉長則由未獲民進黨提名的黨員前鄉長許忠富當選，補選過程張麗善及黨中央傾全力輔選，希望延續2024勝選氣勢，選舉結果一勝一敗，對於改披藍袍的候選人許志豪未能拿下麥寮鄉長，張麗善今受訪表示，國民黨未來在麥寮鄉要繼續努力、加把勁，她也會在政策部分修正，取得鄉親認同。             雲林兩場補選，民進黨僅在虎尾鎮提名林明正，相較藍白兩黨高規格助選，林明正選舉過程中不見黨內大咖輔選，最終僅拿下2千多票，得票率11.7%，遠低於2022年民進黨在虎尾鎮長得票率24.33%．麥寮鄉長雖由民進黨籍許忠富當選，但他此次選舉未獲黨提名支持，是無黨參選，面對這次選舉結果，劉建國表示，這次選舉結果對於民進黨2026大選是更大的挑戰，「不能迴避問題」，要檢討如何讓支持者重燃信心。  民進黨在雲林已失去一席立委，劉建國身為民進黨雲林唯一一席立委，勢必要扛起收復雲林江山的重責大任，他表示，選舉結束了，民進黨該檢討的還是要檢討，不能迴避問題，不僅要凝聚基層支持者的信念跟信心，還要更加謙虛、謙卑面對，有錯誤的地方趕快修正跟調整，讓支持者重回信心，加倍努力。  劉建國在2009年民進黨聲勢跌至谷底時，拿下立委補選，他的勝選為當時的民進黨注入強心針，這次補選，台面上僅看見他為黨提名的林明正輔選，可惜孤臣無力可回天，接下來他要如何在雲林扮演桶箍角色，帶領民進黨重返信心，將是一大考驗。  民進黨雲林縣黨部執行長邱世文說，麥寮鄉長補選民進黨雖然沒有提名，但沒有黨的包袱讓許忠富能盡情發揮，私下黨內同志都全力幫他拉票，幫他打了數百通電話，虎尾選舉是給年輕人一個向下扎根的機會，至少年輕人願意嘗試，以這次的選舉結果來看，民進黨要更加努力，除了基層的服務工作，如何重燃選民的熱情，是未來努力的方向。雲林縣虎尾鎮長補選，民進黨提名林明正（左）落敗，立委劉建國（右）表示，選後該檢討的不能迴避。圖／翻攝自劉建國臉書     劉建國 國民黨 張麗
# ...
